# %%
#IMPORT LIBRARIES
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
consensus_matrix = np.loadtxt(r"runs\CRPEC_run_20240414_031735\GSM4909299\consensus_matrix.csv", delimiter=',')

# %% [markdown]
# # Cluster Map

# %% [markdown]
# Heatmap of Consensus Matrix

# %%
sns.heatmap(consensus_matrix, cmap='viridis', square=True)
plt.title('Consensus Matrix Heatmap')
plt.show()

# %% [markdown]
# Cluster Map

# %%
cg = sns.clustermap(consensus_matrix, cmap='viridis', method='ward')
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)  # Rotate axis labels if needed
plt.show()
